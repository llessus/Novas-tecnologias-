# %% [markdown]
# <a href="https://colab.research.google.com/github/llessus/Novas-tecnologias-/blob/main/AT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1 - Cadastro e análise simples de veículos
#
# Uma concessionária deseja registrar alguns veículos disponíveis para venda.
# Crie um programa em Python que crie uma lista de veículos.
#
# Cada veículo deve ser representado por um dicionário contendo:
# - marca
# - modelo
# - preço
# - ano
#
# Exemplo de estrutura esperada:
#
# ```
# veiculo = {
#     "marca": "Toyota",
#     "modelo": "Corolla",
#     "preco": 120000,
#     "ano": 2022
# }
# ```
#
# O programa deve:
#
# - Adicionar pelo *menos 5 veículos* à lista.
# - Exibir todos os veículos cadastrados.
# - Calcular o *preço médio dos veículos*.
# - Mostrar quais *veículos custam acima da média*.
#
# ### Saída esperada (exemplo)
# ```
# Preço médio dos veículos: 85000
# Veículos acima da média:
# Honda Civic - 110000
# Toyota Corolla - 120000
# ```

# %%
# Solução do exercício 1

# 1. Adicionar pelo menos 5 veículos à lista
veiculos = [
    {"marca": "Toyota", "modelo": "Corolla", "preco": 120000, "ano": 2022},
    {"marca": "Honda", "modelo": "Civic", "preco": 110000, "ano": 2021},
    {"marca": "Volkswagen", "modelo": "Polo", "preco": 75000, "ano": 2020},
    {"marca": "Chevrolet", "modelo": "Onix", "preco": 65000, "ano": 2019},
    {"marca": "Fiat", "modelo": "Pulse", "preco": 95000, "ano": 2023}
]

# 2. Exibir todos os veículos cadastrados
print("--- Veículos Cadastrados ---")
for v in veiculos:
    print(f"{v['marca']} {v['modelo']} - R$ {v['preco']} ({v['ano']})")
print("-" * 28)

# 3. Calcular o preço médio dos veículos
soma_precos = 0
for v in veiculos:
    soma_precos = soma_precos + v["preco"]

preco_medio = soma_precos / len(veiculos)

print(f"Preço médio dos veículos: {preco_medio:.0f}")
print("Veículos acima da média:")

# 4. Mostrar quais veículos custam acima da média
for v in veiculos:
    if v["preco"] > preco_medio:
        print(f"{v['marca']} {v['modelo']} - {v['preco']}")
# Out:
# --- Veículos Cadastrados ---
# Toyota Corolla - R$ 120000 (2022)
# Honda Civic - R$ 110000 (2021)
# Volkswagen Polo - R$ 75000 (2020)
# Chevrolet Onix - R$ 65000 (2019)
# Fiat Pulse - R$ 95000 (2023)
# ----------------------------
# Preço médio dos veículos: 93000
# Veículos acima da média:
# Toyota Corolla - 120000
# Honda Civic - 110000
# Fiat Pulse - 95000

# %% [markdown]
# # Exercício 2 - Sistema simples de financiamento
#
# Uma concessionária oferece financiamento de veículos.
#
# Crie uma função chamada:
#
# ```
# calcular_financiamento(preco, entrada, parcelas)
# ```
#
# A função deve calcular o valor financiado.
#
# ```
# valor_financiado = preco - entrada
# ```
#
# Considerar uma taxa de juros simples de 1.5% ao mês.
#
# Fórmula simplificada:
# ```
# valor_total = valor_financiado * (1 + taxa * parcelas)
# parcela = valor_total / parcelas
# ```
# A função deve retornar o valor da parcela.
#
#
# ### Crie um programa que:
#
# - Defina o preço de um veículo
# - Pergunte ao usuário: valor de entrada e número de parcelas
# - Use a função para calcular o financiamento
# - Exiba o valor da parcela
# - Impedir parcelas maiores que 72 meses
# - Mostrar uma mensagem caso isso ocorra (Número máximo de parcelas é 72.)
#
# ### Exemplo de saída
#
# ```
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 1785.50
# ```

# %%
# Solução do exercício 2


def calcular_financiamento(preco, entrada, parcelas):
    # Calcular o valor que será efetivamente financiado
    valor_financiado = preco - entrada
    taxa = 0.015

    # Calcular o valor total com juros simples e a parcela
    valor_total = valor_financiado * (1 + taxa * parcelas)
    parcela = valor_total / parcelas

    return parcela

# 1. Defina o preço de um veículo
preco_veiculo = 80000
print(f"Preço do veículo: {preco_veiculo}")

# 2. Pergunte ao usuário: valor de entrada e número de parcelas

entrada = float(input("Entrada: "))
parcelas = int(input("Parcelas: "))
# 5. Impedir parcelas maiores que 72 meses e mostrar mensagem
if parcelas > 72:
    print("Número máximo de parcelas é 72.")
else:
    # 3 e 4. Use a função para calcular o financiamento e exiba o valor
    valor_parcela = calcular_financiamento(preco_veiculo, entrada, parcelas)
    print(f"Valor da parcela: {valor_parcela:.2f}")
# Out:
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 2150.00
